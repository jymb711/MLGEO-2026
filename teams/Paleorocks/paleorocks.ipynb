# %% [markdown]
# ## Dependencies

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setup and Run Request
# We are going to use (website name) You can find details about this operation here: (link goes here)

# %% [markdown]
# ## Dec 2025 Stehekin NOAA data

# %%
#NONE OF THIS WORKS AS IS RN

# Define the API URL for quick diversity
#url = "https://api.weather.gov/stations/STRW1/observations?start=2025-12-01T08:00:00Z&end=2025-12-31T08:00:00Z"
headers = {'token' : 'TvAdxJblLeoezyJUbgSJRikNMntqSusm'}
#url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data?stationid=GHCND:USC00458059&startdate=2025-12-01&enddate=2026-01-01"
#url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00024233&units=metric&startdate=2025-05-01&enddate=2025-05-31&limit=1000'
url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USC00458059&datatype=PRCP&limit=1000&startdate=2025-12-01&enddate=2025-12-31'
# Download the CSV data, GHCND:USC00455525
response = requests.get(url, headers=headers)
response.raise_for_status()  # Raise an error if the request failed
StehekinWeatherData = response.json()

# %%
StehekinWeatherData = pd.json_normalize(StehekinWeatherData['results'])
df_SteWeather = pd.dataframe(data=StehekinWeatherData)
df
# Out:
# [{'date': '2025-12-01T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-01T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-01T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-01T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -28},
#  {'date': '2025-12-01T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 6},
#  {'date': '2025-12-02T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 41},
#  {'date': '2025-12-02T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-02T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-02T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 28},
#  {'date': '2025-12-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-02T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-03T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-03T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-03T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-03T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 33},
#  {'date': '2025-12-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -22},
#  {'date': '2025-12-03T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-04T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 15},
#  {'date': '2025-12-04T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-04T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-04T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 44},
#  {'date': '2025-12-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-04T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 44},
#  {'date': '2025-12-05T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 51},
#  {'date': '2025-12-05T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-05T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-05T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 56},
#  {'date': '2025-12-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-05T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-06T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 348},
#  {'date': '2025-12-06T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-06T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-06T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 56},
#  {'date': '2025-12-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-06T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 50},
#  {'date': '2025-12-07T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 183},
#  {'date': '2025-12-07T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-07T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-07T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 50},
#  {'date': '2025-12-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 6},
#  {'date': '2025-12-07T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 50},
#  {'date': '2025-12-08T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 69},
#  {'date': '2025-12-08T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-08T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-08T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 50},
#  {'date': '2025-12-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 6},
#  {'date': '2025-12-08T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 33},
#  {'date': '2025-12-09T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 671},
#  {'date': '2025-12-09T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-09T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-09T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 56},
#  {'date': '2025-12-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 33},
#  {'date': '2025-12-09T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 56},
#  {'date': '2025-12-10T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 589},
#  {'date': '2025-12-10T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 25},
#  {'date': '2025-12-10T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 25},
#  {'date': '2025-12-10T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 61},
#  {'date': '2025-12-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-10T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-13T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 665},
#  {'date': '2025-12-13T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-13T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-13T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 72},
#  {'date': '2025-12-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-13T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 50},
#  {'date': '2025-12-14T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-14T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-14T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 50},
#  {'date': '2025-12-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 17},
#  {'date': '2025-12-14T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 22},
#  {'date': '2025-12-15T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 277},
#  {'date': '2025-12-15T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-15T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-15T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 61},
#  {'date': '2025-12-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 22},
#  {'date': '2025-12-15T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 56},
#  {'date': '2025-12-16T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 183},
#  {'date': '2025-12-16T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-16T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-16T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 72},
#  {'date': '2025-12-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 33},
#  {'date': '2025-12-16T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 39},
#  {'date': '2025-12-17T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 699},
#  {'date': '2025-12-17T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-17T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-17T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 39},
#  {'date': '2025-12-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 6},
#  {'date': '2025-12-17T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 39},
#  {'date': '2025-12-18T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 18},
#  {'date': '2025-12-18T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-18T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-18T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 39},
#  {'date': '2025-12-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-18T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-19T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 376},
#  {'date': '2025-12-19T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 51},
#  {'date': '2025-12-19T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 51},
#  {'date': '2025-12-19T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 22},
#  {'date': '2025-12-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-19T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-20T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 89},
#  {'date': '2025-12-20T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 25},
#  {'date': '2025-12-20T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 76},
#  {'date': '2025-12-20T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 22},
#  {'date': '2025-12-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-20T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-21T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 168},
#  {'date': '2025-12-21T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 13},
#  {'date': '2025-12-21T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 76},
#  {'date': '2025-12-21T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-21T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-22T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 56},
#  {'date': '2025-12-22T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-22T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 51},
#  {'date': '2025-12-22T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 22},
#  {'date': '2025-12-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -17},
#  {'date': '2025-12-22T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -11},
#  {'date': '2025-12-23T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 117},
#  {'date': '2025-12-23T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-23T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 51},
#  {'date': '2025-12-23T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -17},
#  {'date': '2025-12-23T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -11},
#  {'date': '2025-12-24T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 173},
#  {'date': '2025-12-24T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 127},
#  {'date': '2025-12-24T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 203},
#  {'date': '2025-12-24T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -17},
#  {'date': '2025-12-24T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-25T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 71},
#  {'date': '2025-12-25T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 25},
#  {'date': '2025-12-25T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 203},
#  {'date': '2025-12-25T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -22},
#  {'date': '2025-12-25T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-26T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 76},
#  {'date': '2025-12-26T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 25},
#  {'date': '2025-12-26T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',I,H,0800',
#   'value': 0},
#  {'date': '2025-12-26T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 6},
#  {'date': '2025-12-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-26T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-27T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 66},
#  {'date': '2025-12-27T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',I,H,',
#   'value': 25},
#  {'date': '2025-12-27T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',I,H,0800',
#   'value': 229},
#  {'date': '2025-12-27T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 11},
#  {'date': '2025-12-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -28},
#  {'date': '2025-12-27T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -28},
#  {'date': '2025-12-28T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-28T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-28T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 229},
#  {'date': '2025-12-28T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -17},
#  {'date': '2025-12-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -67},
#  {'date': '2025-12-28T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -50},
#  {'date': '2025-12-29T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-29T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-29T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 229},
#  {'date': '2025-12-29T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -11},
#  {'date': '2025-12-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -50},
#  {'date': '2025-12-29T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -28},
#  {'date': '2025-12-30T00:00:00',
#   'datatype': 'PRCP',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 0},
#  {'date': '2025-12-30T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,',
#   'value': 0},
#  {'date': '2025-12-30T00:00:00',
#   'datatype': 'SNWD',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': 203},
#  {'date': '2025-12-30T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -6},
#  {'date': '2025-12-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -28},
#  {'date': '2025-12-30T00:00:00',
#   'datatype': 'TOBS',
#   'station': 'GHCND:USC00458059',
#   'attributes': ',,H,0800',
#   'value': -17}]

# %% [markdown]
# ## Examine and Visualize Data

# %%
#AGAIN, DOES NOT WORK YET. JUST PLAYING WITH PD CODE 
# Now, load the downloaded data into pandas
with open(localFile, "r", encoding="utf-8") as f:
   data = json.load(f)

# Normalize into a DataFrame
df = pd.json_normalize(data["features"])

# Inspect the result
print(df.head())
#df.to_csv('weatherdata.csv')

# Let us inspect the columns
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 #AGAIN, DOES NOT WORK YET. JUST PLAYING WITH PD CODE
#       2 # Now, load the downloaded data into pandas
# ----> 3 with open(localFile, "r", encoding="utf-8") as f:
#       4    data = json.load(f)
#       6 # Normalize into a DataFrame
#
# NameError: name 'localFile' is not defined

# %%
# Calculate the mid-point of each interval and add as a new column
df['mid'] = (df['max_ma'] + df['min_ma']) / 2

# Finally, let us plot
plt.figure(figsize=(10, 5))
plt.plot(df['mid'], df['sampled_in_bin'], marker='o')
plt.xlabel('Time (Ma)')
plt.ylabel('Number families')
plt.gca().invert_xaxis()  # Geological time: older to the left
plt.tight_layout()
plt.show()
